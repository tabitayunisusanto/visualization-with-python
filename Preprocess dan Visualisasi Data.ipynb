# %% [markdown]
# # Tugas Data Mining A Prepocessing dan Visualisasi data
#     Tabita Yuni Susanto   06211740000026
#     Fajriansyah D         06211740000096
#
#   [Klik disini untuk link data set](https://www.kaggle.com/madhansing/bank-loan2)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
data=pd.read_csv('E:/fd/datmin/madfhantr.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# #### Data yang digunakan adalah data training dari Dataset BankLoan2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ### Count of Missing Value

# %%
np.sum(data.isnull())
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ### Persentase Missing Value

# %%
np.sum(data.isnull())/len(data)*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %% [markdown]
# ### Terdapat Missing Value pada 7 variabel sehingga dilakukan Imputation

# %%
data['ApplicantIncome'] = data['ApplicantIncome'].fillna((data['ApplicantIncome'].median())) 
data['CoapplicantIncome'] = data['CoapplicantIncome'].fillna((data['CoapplicantIncome'].median())) 
data['LoanAmount'] = data['LoanAmount'].fillna((data['LoanAmount'].mean())) 
data['Loan_Amount_Term'] = data['Loan_Amount_Term'].fillna((data['Loan_Amount_Term'].mean())) 
np.sum(data.isnull())
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data['Gender']=data['Gender'].fillna(data['Gender'].mode()[0])
data['Married']=data['Married'].fillna(data['Married'].mode()[0])
data['Dependents']=data['Dependents'].fillna(data['Dependents'].mode()[0])
data['Self_Employed']=data['Self_Employed'].fillna(data['Self_Employed'].mode()[0])
data['Credit_History']=data['Credit_History'].fillna(data['Credit_History'].mode()[0])
np.sum(data.isnull())
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.describe(include='all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    614     614        614       614           614
# unique       614      2       2          4         2             2
# top     LP001560   Male     Yes          0  Graduate            No
# freq           1    502     401        360       480           532
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  614.000000        614.000000
# ...

# %% [markdown]
# ### Encode Labels

# %%
from sklearn.preprocessing import LabelEncoder
data['Credit_History'] = LabelEncoder().fit_transform(data['Credit_History'])
data.head(n=10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# ...

# %% [markdown]
# ### Visualisasi Data

# %%
sns.lmplot("ApplicantIncome", "LoanAmount", data, fit_reg=True, hue='Loan_Status', legend=False)
plt.legend(loc='lower right')
plt.show()

# %%
plt.subplot(221)
data['Loan_Status'].value_counts().plot.bar(title='Count of Loan Status')
plt.subplot(222)
data['Loan_Status'].value_counts(normalize=True).plot.bar(figsize=(10,10), title='Persentase Kategori Loan Status')

# %%
from pylab import *
plt.plot([1,2,3])
plt.subplot(241)
data['Gender'].value_counts().plot.bar(figsize=(20,10), title= 'Gender') 
grid(True)
plt.subplot(242) 
data['Married'].value_counts().plot.bar(title= 'Married') 
grid(True)
plt.subplot(243) 
data['Self_Employed'].value_counts().plot.bar(title= 'Self_Employed') 
grid(True)
plt.subplot(244) 
data['Credit_History'].value_counts().plot.bar(title= 'Credit_History') 
grid(True)
plt.subplot(245) 
data['Education'].value_counts().plot.bar(title= 'Education') 
grid(True)
plt.subplot(246) 
data['Dependents'].value_counts().plot.bar(title= 'Dependents') 
grid(True)
plt.subplot(247)
data['Property_Area'].value_counts().plot.bar(title='Property_Area')
grid(True)
show()

# %% [markdown]
# ### *Barchart* diatas menunjukkan Jumlah dari masing masing kategori pada variabel yang bertipe data kategorikal yaitu *Gender*, *Credit History*, *Self Employed*, *Education*, *Dependents*, dan Status Pernikahan

# %%
Gender=pd.crosstab(data['Loan_Status'],data['Credit_History'])
Gender.div(Gender.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))
Property=pd.crosstab(data['Property_Area'],data['Loan_Status']) 
Property.div(Property.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))
Married=pd.crosstab(data['Loan_Status'],data['Married'])
Married.div(Married.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

self=pd.crosstab(data['Loan_Status'],data['Self_Employed'])
self.div(self.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))


plt.show()

# %%
f, ax = plt.subplots(figsize=(18, 15)) 
ctype = ['Urban','Rural','Semiurban']
plt.subplot(441)
wvp = sns.barplot(x=data.Loan_Status, y=data.ApplicantIncome, hue=data.Property_Area, hue_order=ctype, data=data)

plt.subplot(442)
wvp = sns.barplot(x=data.Loan_Status, y=data.CoapplicantIncome, hue=data.Property_Area, hue_order=ctype, data=data)

plt.subplot(443)
wvp = sns.barplot(x=data.Loan_Status, y=data.Loan_Amount_Term, hue=data.Property_Area, hue_order=ctype, data=data)

plt.subplot(444)
wvp = sns.barplot(x=data.Loan_Status, y=data.LoanAmount, hue=data.Property_Area, hue_order=ctype, data=data)

plt.subplot(445)
wvp = sns.barplot(x=data.Loan_Status, y=data.ApplicantIncome, hue=data.Self_Employed, data=data)

plt.subplot(446)
wvp = sns.barplot(x=data.Loan_Status, y=data.CoapplicantIncome, hue=data.Self_Employed, data=data)

plt.subplot(447)
wvp = sns.barplot(x=data.Loan_Status, y=data.LoanAmount, hue=data.Self_Employed, data=data)

plt.subplot(448)
wvp = sns.barplot(x=data.Loan_Status, y=data.Loan_Amount_Term, hue=data.Self_Employed, data=data)

# %%
g=sns.PairGrid(data,hue="Loan_Status")
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()
plt.show()

# %%
korelasi = data.corr() 
f, ax = plt.subplots(figsize=(7, 6)) 
sns.heatmap(korelasi, vmax=1, square=True, cmap="BuPu",annot=True, fmt='.1f',ax=ax);
plt.title("Korelasi antar kolom data Bank Loan")
plt.show()

# %%
plt.figure(5)
plt.subplot(431)
data['Gender'].value_counts().plot.pie(autopct='%.4f%%', shadow=True,figsize=(15,20))
plt.subplot(432) 
data['Married'].value_counts().plot.pie(autopct='%.4f%%', shadow=True)
plt.subplot(433) 
data['Self_Employed'].value_counts().plot.pie(autopct='%.4f%%', shadow=True)
plt.subplot(434) 
data['Credit_History'].value_counts().plot.pie(autopct='%.4f%%', shadow=True)
plt.subplot(435) 
data['Education'].value_counts().plot.pie(autopct='%.4f%%', shadow=True)
plt.subplot(436) 
data['Dependents'].value_counts().plot.pie(autopct='%.4f%%', shadow=True)

plt.subplot(437)
data['Property_Area'].value_counts().plot.pie(autopct='%.4f%%', shadow=True)
plt.show()

# %%
plt.figure(6) 
f, ax = plt.subplots(figsize=(18, 30)) 
plt.subplot(521) 

df=data.dropna() 
sns.distplot(df['LoanAmount'])
plt.subplot(522) 
sns.boxplot(y='LoanAmount', x='Loan_Status', 
                 data=df, 
            palette="colorblind")
plt.subplot(523)
sns.distplot(df['ApplicantIncome'])
plt.subplot(524) 
sns.boxplot(y='ApplicantIncome', x='Loan_Status', 
                 data=df, 
                 palette="colorblind")
plt.subplot(525)
sns.distplot(df['CoapplicantIncome'])
plt.subplot(526) 
sns.boxplot(y='CoapplicantIncome', x='Loan_Status', 
                 data=df, 
                 palette="colorblind")
plt.subplot(527)
sns.distplot(df['Loan_Amount_Term'])
plt.subplot(528) 
sns.boxplot(y='Loan_Amount_Term', x='Loan_Status', 
                 data=df, 
                 palette="colorblind")
plt.show()

# %%
sns.pairplot(data, hue="Loan_Status");

# %%
sns.pairplot(data, hue="Property_Area")

# %% [markdown]
# ### Identifikasi Outlier dengan Standar Deviasi

# %% [markdown]
# ### Jumlah Outlier pada Applicant Income:

# %%
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from numpy import std
data1=data.ApplicantIncome
data_mean, data_std = mean(data1), std(data1)
cut_off = data_std * 3
lower, upper = data_mean - cut_off, data_mean + cut_off
# identify outliers
outliers = [x for x in data1 if x < lower or x > upper]
print('Identified outliers: %d' % len(outliers))
# remove outliers
outliers_removed = [x for x in data1 if x >= lower and x <= upper]
print('Non-outlier observations: %d' % len(outliers_removed))
# Out:
# Identified outliers: 8
# Non-outlier observations: 606

# %% [markdown]
# ### Jumlah Outlier pada CoapplicantIncome :

# %%
data2=data.CoapplicantIncome
data_mean, data_std = mean(data2), std(data2)
cut_off = data_std * 3
lower, upper = data_mean - cut_off, data_mean + cut_off
outliers = [x for x in data2 if x < lower or x > upper]
print('Identified outliers: %d' % len(outliers))
outliers_removed = [x for x in data2 if x >= lower and x <= upper]
print('Non-outlier observations: %d' % len(outliers_removed))
# Out:
# Identified outliers: 6
# Non-outlier observations: 608

# %% [markdown]
# ### Jumlah Outlier pada Loan Amount

# %%
data3=data.LoanAmount
data_mean, data_std = mean(data3), std(data3)
cut_off = data_std * 3
lower, upper = data_mean - cut_off, data_mean + cut_off
outliers = [x for x in data3 if x < lower or x > upper]
print('Identified outliers: %d' % len(outliers))
outliers_removed = [x for x in data3 if x >= lower and x <= upper]
print('Non-outlier observations: %d' % len(outliers_removed))
# Out:
# Identified outliers: 15
# Non-outlier observations: 599

# %% [markdown]
# ### Jumlah outlier pada Loan Amount Term

# %%
data4=data.Loan_Amount_Term
data_mean, data_std = mean(data4), std(data4)
cut_off = data_std * 3
lower, upper = data_mean - cut_off, data_mean + cut_off
outliers = [x for x in data4 if x < lower or x > upper]
print('Identified outliers: %d' % len(outliers))
outliers_removed = [x for x in data4 if x >= lower and x <= upper]
print('Non-outlier observations: %d' % len(outliers_removed))
# Out:
# Identified outliers: 12
# Non-outlier observations: 602

# %%
data.groupby(['Loan_Status'])['ApplicantIncome'].mean()
# Out:
# Loan_Status
# N    5446.078125
# Y    5384.068720
# Name: ApplicantIncome, dtype: float64

# %%
data.groupby(['Loan_Status'])['CoapplicantIncome'].mean()
# Out:
# Loan_Status
# N    1877.807292
# Y    1504.516398
# Name: CoapplicantIncome, dtype: float64

# %%
data.groupby(['Loan_Status'])['LoanAmount'].mean()
# Out:
# Loan_Status
# N    150.945488
# Y    144.349606
# Name: LoanAmount, dtype: float64

# %%
data.groupby(['Loan_Status'])['Loan_Amount_Term'].mean()
# Out:
# Loan_Status
# N    344.000000
# Y    341.090047
# Name: Loan_Amount_Term, dtype: float64
